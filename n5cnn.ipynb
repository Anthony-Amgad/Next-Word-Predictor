# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Embedding,LSTM,Dense
from tensorflow.keras.models import Sequential
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.optimizers import Adam
from keras import regularizers
import pickle
import numpy as np
import os
import pandas as pd
import re

# from google.colab import drive
# drive.mount('/content/drive')
# %cp -av "/content/drive/MyDrive/fknews.txt" "/content"

# %%
# Load the JSON file into a dictionary
import json
with open('syntheticPC.json', 'r') as f:
    data = json.load(f)

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame.from_dict(data)

# Print the unique values in the 'tag' column
print(df['tag'].unique())
df.head()
# Out:
# ['phone call' 'meeting' 'face-to-face conversation' 'general chatting'
#  'presentation' 'training']
#               id                        tag                title  \
# 0  190329_J07_03                 phone call  伝言への折り返し電話打ち合わせ日程調整
# 1  190329_J06_11                    meeting    株主総会に関する役員向け説明（２）
# 2  190329_J06_10                    meeting    株主総会に関する役員向け説明（１）
# 3  190329_J06_09  face-to-face conversation        信託銀行から株主名簿を受領
# 4  190329_J06_08  face-to-face conversation           株主総会への臨場要請
#
#   original_language                                       conversation
# 0                ja  [{'no': 1, 'ja_speaker': '土井さん', 'en_speaker':...
# 1                ja  [{'no': 1, 'ja_speaker': '高田さん', 'en_speaker':...
# 2                ja  [{'no': 1, 'ja_speaker': '友井さん', 'en_speaker':...
# 3                ja  [{'no': 1, 'ja_speaker': '高田さん', 'en_speaker':...
# 4                ja  [{'no': 1, 'ja_speaker': '高田さん', 'en_speaker':...

# %%
df_convs = pd.concat([pd.json_normalize(df['conversation'][i]) for i in range(len(df))],ignore_index=True)
train_en = df_convs["en_sentence"].values.tolist()

# %%
train_en[:10]
# Out:
# ['Hi this is the systems development department of Company K.',
#  'My name is Takaichi from Company H.',
#  'Thank you as always.',
#  'Thank you as always as well.',
#  'Is Inada-san there?',
#  'It seems I got a call from him around 1 hour ago.',
#  'Yes, let me switch you over.',
#  'Please wait a moment.',
#  'Inada-san, you have a call from Mr. Takaichi of Company H.',
#  'Hello, this is Inada.']

# %%
text = ' '.join(train_en[:10000])
print('length of the corpus is: :', len(text))
del data
# Out:
# length of the corpus is: : 532978

# %%
tokens = text.split(" ")
tokens = list(filter(lambda t: t != "", tokens))
tokens
# Out:
# ['Hi',
#  'this',
#  'is',
#  'the',
#  'systems',
#  'development',
#  'department',
#  'of',
#  'Company',
#  'K.',
#  'My',
#  'name',
#  'is',
#  'Takaichi',
#  'from',
#  'Company',
#  'H.',
#  'Thank',
#  'you',
#  'as',
#  'always.',
#  'Thank',
#  'you',
#  'as',
#  'always',
#  'as',
#  'well.',
#  'Is',
#  'Inada-san',
#  'there?',
#  'It',
#  'seems',
#  'I',
#  'got',
#  'a',
#  'call',
#  'from',
#  'him',
#  'around',
#  '1',
#  'hour',
#  'ago.',
#  'Yes,',
#  'let',
#  'me',
#  'switch',
#  'you',
#  'over.',
#  'Please',
#  'wait',
#  'a',
#  'moment.',
#  'Inada-san,',
#  'you',
#  'have',
#  'a',
#  'call',
#  'from',
#  'Mr.',
#  'Takaichi',
#  'of',
#  'Company',
#  'H.',
#  'Hello,',
#  'this',
#  'is',
#  'Inada.',
#  'This',
#  'is',
#  'Takaichi',
#  'from',
#  'Company',
#  'H.',
#  'Thank',
#  'you.',
#  'Thank',
#  'you',
#  'as',
#  'always.',
#  'Thank',
#  'you',
#  'for',
#  'the',
#  'call',
#  'earlier.',
#  'Sorry',
#  'I',
#  'was',
#  'out.',
#  'Not',
#  'at',
#  'all,',
#  "I'm",
#  'also',
#  'sorry',
#  'for',
#  'calling',
#  'when',
#  'you',
#  'were',
#  'busy.',
#  'We',
#  'are',
#  'going',
#  'to',
#  'Company',
#  'A',
#  'next',
#  'Monday,',
#  'right?',
#  'I',
#  'thought',
#  'we',
#  'should',
#  'maybe',
#  'have',
#  'a',
#  'meeting',
#  'once',
#  'for',
#  'that.',
#  'Right,',
#  "let's",
#  'do',
#  'it.',
#  'We',
#  'have',
#  'to',
#  'prepare',
#  'materials',
#  'too',
#  'so',
#  'we',
#  'should',
#  'do',
#  'it',
#  'earlier.',
#  'Takaichi-san,',
#  'you',
#  'said',
#  'you',
#  'are',
#  'available',
#  'anytime?',
#  'Yes,',
#  'when',
#  'is',
#  'good',
#  'for',
#  'you,',
#  'Inada-san?',
#  'If',
#  'it',
#  'is',
#  'soon',
#  'then...',
#  'How',
#  'about',
#  'around',
#  'ten',
#  'thirty',
#  'in',
#  'the',
#  'morning',
#  'tomorrow?',
#  'I',
#  'will',
#  'go',
#  'to',
#  'your',
#  'place.',
#  'Really?',
#  'Sorry',
#  'for',
#  'the',
#  'trouble.',
#  'I',
#  'was',
#  'thinking',
#  'I',
#  'can',
#  'go',
#  'to',
#  'your',
#  'place',
#  'though.',
#  "It's",
#  'okay,',
#  "it's",
#  'close.',
#  'Okay,',
#  'I',
#  'will',
#  'go',
#  'to',
#  'your',
#  'place',
#  'around',
#  'ten',
#  'thirty',
#  'tomorrow.',
#  'Okay,',
#  'got',
#  'it.',
#  'Thank',
#  'you',
#  'very',
#  'much.',
#  'Alright,',
#  "I'll",
#  'wait',
#  'for',
#  'you',
#  'tomorrow.',
#  'Thank',
#  'you.',
#  'Thank',
#  'you.',
#  'The',
#  'overall',
#  'schedule',
#  'for',
#  'the',
#  'general',
#  'meeting',
#  'of',
#  'shareholders',
#  'will',
#  'be',
#  'as',
#  'shown',
#  'on',
#  'this',
#  'material',
#  'here.',
#  'Among',
#  'that,',
#  'I',
#  'will',
#  'select',
#  'the',
#  'topics',
#  'related',
#  'to',
#  'all',
#  'the',
#  'executives',
#  'and',
#  'explain',
#  'them.',
#  'First',
#  'of',
#  'all,',
#  'on',
#  'the',
#  'day',
#  'of',
#  'the',
#  'general',
#  'meeting,',
#  'we',
#  'will',
#  'explain',
#  'and',
#  'proceed',
#  'it',
#  'according',
#  'to',
#  'the',
#  'scenario',
#  'in',
#  'front',
#  'of',
#  'you.',
#  'We',
#  'will',
#  'review',
#  'overall',
#  'flow',
#  'from',
#  'the',
#  'entrance',
#  'and',
#  'the',
#  'exit',
#  'for',
#  'the',
#  'executives',
#  'and',
#  'also',
#  'go',
#  'over',
#  'the',
#  'scenario',
#  '3',
#  'times',
#  'including',
#  'today.',
#  'We',
#  'will',
#  'have',
#  'Nose-san',
#  'attend',
#  'all',
#  'of',
#  'it',
#  'so',
#  'please',
#  'point',
#  'out',
#  'things',
#  'that',
#  'we',
#  'should',
#  'improve',
#  'on.',
#  'Today,',
#  'we',
#  'will',
#  'do',
#  'a',
#  'rehearsal',
#  'using',
#  'this',
#  'meeting',
#  'room',
#  'here',
#  'after',
#  'this.',
#  'Next',
#  'week,',
#  'we',
#  'plan',
#  'on',
#  'having',
#  'a',
#  'rehearsal',
#  'internally',
#  'with',
#  'only',
#  'the',
#  'board',
#  'of',
#  'directors',
#  'and',
#  'the',
#  'full-time',
#  'corporate',
#  'auditor.',
#  'On',
#  'the',
#  'day',
#  'before',
#  'the',
#  'general',
#  'meeting,',
#  'we',
#  'will',
#  'do',
#  'a',
#  'rehearsal',
#  'with',
#  'everyone',
#  'in',
#  'attendance',
#  'at',
#  'the',
#  'actual',
#  'venue.',
#  'On',
#  'the',
#  'rehearsal',
#  'the',
#  'day',
#  'before,',
#  'we',
#  'will',
#  'also',
#  'have',
#  'Ota-san',
#  'who',
#  'is',
#  'the',
#  'general',
#  'counsel',
#  'and',
#  'is',
#  'in',
#  'attendance',
#  'today',
#  'to',
#  'come',
#  'as',
#  'well.',
#  'Yes,',
#  'I',
#  'will',
#  'keep',
#  'my',
#  'schedule',
#  'open.',
#  'We',
#  'will',
#  'also',
#  'have',
#  'an',
#  'accountant',
#  'who',
#  'is',
#  'our',
#  'auditor',
#  'on',
#  'stand-by',
#  'in',
#  'the',
#  'back',
#  'only',
#  'for',
#  'the',
#  'day',
#  'of',
#  'the',
#  'general',
#  'meeting',
#  'and',
#  'I',
#  'have',
#  'asked',
#  'him',
#  'to',
#  'provide',
#  'support',
#  'when',
#  'needed.',
#  'In',
#  'regards',
#  'to',
#  'the',
#  'proceedings,',
#  'it',
#  'will',
#  'be',
#  'fine',
#  'if',
#  'you',
#  'say',
#  'what',
#  'is',
#  'on',
#  'the',
#  'script',
#  'on',
#  'hand.',
#  'But,',
#  'things',
#  'may',
#  'not',
#  'go',
#  'as',
#  'planned',
#  'for',
#  'the',
#  'questions',
#  'and',
#  'answers.',
#  'I',
#  'have',
#  'made',
#  'a',
#  'list',
#  'of',
#  'questions',
#  'which',
#  'I',
#  'anticipate',
#  'will',
#  'be',
#  'asked',
#  'and',
#  'have',
#  'answers',
#  'for',
#  'it',
#  'in',
#  'the',
#  'same',
#  'material',
#  'in',
#  'front',
#  'of',
#  'you.',
#  'I',
#  'think',
#  'it',
#  'generally',
#  'covers',
#  'the',
#  'topics',
#  'that',
#  'the',
#  'shareholders',
#  'will',
#  'most',
#  'likely',
#  'ask',
#  'for',
#  'this',
#  'quarter.',
#  'There',
#  'is',
#  'quite',
#  'a',
#  'bit',
#  'so',
#  "I'd",
#  'like',
#  'to',
#  'ask',
#  'each',
#  'of',
#  'the',
#  'directors',
#  'to',
#  'master',
#  'their',
#  'own',
#  'parts.',
#  'There',
#  'is',
#  'also',
#  'a',
#  'possibility',
#  'of',
#  'being',
#  'asked',
#  'specific',
#  'figures',
#  'by',
#  'the',
#  'shareholders.',
#  'In',
#  'that',
#  'case,',
#  'we',
#  'will',
#  'have',
#  'a',
#  'team',
#  'of',
#  'admins',
#  'including',
#  'myself',
#  'in',
#  'the',
#  'back',
#  'to',
#  'support',
#  'you',
#  'so',
#  'please',
#  "don't",
#  'worry.',
#  'I',
#  'think',
#  'I',
#  'should',
#  'generally',
#  'be',
#  'answering',
#  'the',
#  'questions',
#  'from',
#  'the',
#  'shareholders',
#  'as',
#  'I',
#  'am',
#  'the',
#  'chairman.',
#  'But',
#  'what',
#  'should',
#  'we',
#  'do',
#  'if',
#  'the',
#  'shareholders',
#  'would',
#  'like',
#  'the',
#  'questions',
#  'answered',
#  'by',
#  'a',
#  'specific',
#  'director?',
#  'I',
#  'think',
#  'it',
#  'will',
#  'be',
#  'more',
#  'sincere',
#  'if',
#  'the',
#  'specified',
#  'director',
#  'can',
#  'explain',
#  'it',
#  'to',
#  'an',
#  'extent',
#  'of',
#  'course.',
#  'But',
#  'if',
#  'you',
#  'can',
#  'judge',
#  'that',
#  'the',
#  'chairman',
#  'should',
#  'answer',
#  'directly,',
#  'you',
#  'can',
#  'stop',
#  'them.',
#  'It',
#  'will',
#  'depend',
#  'on',
#  'the',
#  'situation.',
#  'I',
#  'think',
#  'another',
#  'idea',
#  'would',
#  'be',
#  'to',
#  'have',
#  'the',
#  'specified',
#  'director',
#  'answer',
#  'first',
#  'then',
#  'the',
#  'chairman',
#  'can',
#  'provide',
#  'a',
#  'follow-up',
#  'after.',
#  'Okay,',
#  "let's",
#  'go',
#  'with',
#  'that.',
#  'Okay,',
#  "I'd",
#  'like',
#  'to',
#  'actually',
#  'do',
#  'a',
#  'rehearsal',
#  'and',
#  'go',
#  'through',
#  'the',
#  'whole',
#  'thing.',
#  'We',
#  'will',
#  'go',
#  'according',
#  'to',
#  'the',
#  'scenario',
#  'and',
#  'also',
#  'do',
#  'questions',
#  'and',
#  'answers.',
#  'Nose-san',
#  'and',
#  'I',
#  'will',
#  'be',
#  'the',
#  'shareholders',
#  'and',
#  'will',
#  'ask',
#  'questions.',
#  'Please',
#  'note',
#  'that',
#  'the',
#  'questions',
#  'may',
#  'not',
#  'be',
#  'exactly',
#  'what',
#  'is',
#  'on',
#  'the',
#  'anticipated',
#  'questions',
#  'list.',
#  'If',
#  'you',
#  'guys',
#  'are',
#  'the',
#  'shareholders,',
#  'I',
#  'think',
#  'we',
#  'will',
#  'be',
#  'showered',
#  'with',
#  'tougher',
#  'questions',
#  'than',
#  'the',
#  'real',
#  'thing.',
#  'It',
#  'will',
#  'feel',
#  'more',
#  'tense',
#  'in',
#  'a',
#  'good',
#  'way,',
#  'right?',
#  'Please',
#  'go',
#  'easy',
#  'on',
#  'us.',
#  'Well,',
#  'that',
#  "won't",
#  'be',
#  'good',
#  'practice!',
#  'Alright,',
#  "let's",
#  'pretend',
#  'the',
#  'door',
#  'of',
#  'the',
#  'meeting',
#  'room',
#  'is',
#  'the',
#  'entrance',
#  'of',
#  'the',
#  'venue',
#  'on',
#  'the',
#  'day',
#  'and',
#  'start',
#  'from',
#  'there.',
#  'Okay,',
#  "I'd",
#  'like',
#  'to',
#  'start',
#  'now',
#  'so',
#  "let's",
#  'go.',
#  'It',
#  'seems',
#  'everyone',
#  'is',
#  'here',
#  'so',
#  "let's",
#  'start',
#  'the',
#  'executive',
#  'meeting',
#  'in',
#  'regards',
#  'to',
#  'the',
#  'general',
#  'meeting',
#  'of',
#  'shareholders',
#  'now.',
#  'Okay,',
#  'can',
#  'you',
#  'proceed',
#  'with',
#  'this',
#  'Takada?',
#  'Yes,',
#  'I',
#  'will',
#  'be',
#  'proceeding',
#  'this.',
#  'First',
#  'of',
#  'all,',
#  'we',
#  'will',
#  'have',
#  'Nose-san',
#  'from',
#  'Trust',
#  'Company',
#  'M',
#  'to',
#  'talk',
#  'about',
#  'the',
#  'trends',
#  'of',
#  'the',
#  'general',
#  'meetings',
#  'of',
#  'each',
#  'company',
#  'this',
#  'quarter.',
#  'Nose,',
#  'please',
#  'go',
#  'ahead.',
#  'Good',
#  'morning',
#  'everyone.',
#  'My',
#  'name',
#  'is',
#  'Nose',
#  'from',
#  'Trust',
#  'Company',
#  'M',
#  'and',
#  'I',
#  'will',
#  'be',
#  'helping',
#  'out',
#  'with',
#  'your',
#  "company's",
#  'general',
#  'meeting',
#  'this',
#  'year',
#  'again.',
#  'I',
#  'look',
#  'forward',
#  'to',
#  'working',
#  'with',
#  'you.',
#  'As',
#  'Takada-san',
#  'mentioned',
#  'earlier,',
#  'I',
#  'will',
#  'be',
#  'talking',
#  'about',
#  'the',
#  'trend',
#  'and',
#  'such',
#  'in',
#  'regards',
#  'to',
#  'running',
#  'the',
#  'general',
#  'meeting.',
#  'Also,',
#  'I',
#  'am',
#  'especially',
#  'hoping',
#  'to',
#  'talk',
#  'about',
#  'the',
#  'situation',
#  'from',
#  'your',
#  "company's",
#  'perspective',
#  'so',
#  'I',
#  'look',
#  'forward',
#  'to',
#  'working',
#  'with',
#  'you.',
#  'So',
#  'I',
#  'will',
#  'first',
#  'talk',
#  'about',
#  'the',
#  'situation',
#  'of',
#  'general',
#  'meetings',
#  'at',
#  'other',
#  'companies',
#  'this',
#  'quarter.',
#  'My',
#  'impression',
#  'is',
#  'that',
#  'there',
#  'were',
#  'a',
#  'lot',
#  'of',
#  'meek',
#  'general',
#  'meetings',
#  'overall',
#  'this',
#  'quarter.',
#  'There',
#  'were',
#  'a',
#  'lot',
#  'of',
#  'companies',
#  'whose',
#  'performance',
#  'were',
#  'good',
#  'and',
#  'stable',
#  'this',
#  'quarter',
#  'so',
#  "that's",
#  'is',
#  'probably',
#  'the',
#  'big',
#  'reason.',
#  'There',
#  'were',
#  'many',
#  'companies',
#  'who',
#  'finished',
#  'in',
#  'around',
#  '1',
#  'hour',
#  'and',
#  'the',
#  'questions',
#  'and',
#  'answers',
#  'went',
#  'very',
#  'smoothly.',
#  'However,',
#  'in',
#  'regards',
#  'to',
#  'some',
#  'companies',
#  'that',
#  ...]

# %%
train_len = 5+1

text_sequences = []

for i in range(train_len, len(tokens)):

    seq = tokens[i-train_len:i]

    text_sequences.append(seq)

# %%
' '.join(text_sequences[0])
# Out:
# 'Hi this is the systems development'

# %%
len(text_sequences) #Every sentence is containing 26 words
# Out:
# 99691

# %%
len(tokens) # These are total number of words in the whole novel
# Out:
# 99697

# %%
tokenizer = Tokenizer()
tokenizer.fit_on_texts(text_sequences)
sequences = tokenizer.texts_to_sequences(text_sequences)

# %%
del text
print(len(sequences[0]))
print(sequences[0])
# Out:
# 6
# [645, 19, 7, 1, 1055, 436]

# %%
del text_sequences
tokenizer.index_word
# Out:
# {1: 'the',
#  2: 'i',
#  3: 'to',
#  4: 'you',
#  5: 'a',
#  6: 'it',
#  7: 'is',
#  8: 'and',
#  9: 'of',
#  10: 'for',
#  11: 'we',
#  12: 'in',
#  13: 'that',
#  14: 'be',
#  15: 'will',
#  16: 'have',
#  17: 'so',
#  18: 'can',
#  19: 'this',
#  20: 'on',
#  21: 'if',
#  22: 'are',
#  23: 'but',
#  24: 'with',
#  25: 'from',
#  26: 'as',
#  27: 'about',
#  28: 'your',
#  29: 'at',
#  30: 'do',
#  31: 'like',
#  32: 'yes,',
#  33: 'thank',
#  34: 'was',
#  35: "it's",
#  36: 'there',
#  37: 'my',
#  38: 'our',
#  39: 'not',
#  40: 'would',
#  41: 'what',
#  42: 'they',
#  43: 'think',
#  44: 'how',
#  45: 'company',
#  46: "i'm",
#  47: 'oh,',
#  48: 'please',
#  49: "that's",
#  50: 'me',
#  51: 'when',
#  52: 'an',
#  53: 'by',
#  54: 'get',
#  55: 'you.',
#  56: 'just',
#  57: 'all',
#  58: 'good',
#  59: 'should',
#  60: 'it.',
#  61: 'time',
#  62: 'go',
#  63: "don't",
#  64: 'up',
#  65: 'he',
#  66: 'know',
#  67: 'then',
#  68: 'next',
#  69: 'okay,',
#  70: 'need',
#  71: 'one',
#  72: 'very',
#  73: "i'll",
#  74: 'them',
#  75: 'people',
#  76: 'take',
#  77: 'make',
#  78: 'going',
#  79: 'well,',
#  80: 'any',
#  81: 'more',
#  82: 'or',
#  83: 'some',
#  84: 'who',
#  85: 'other',
#  86: 'been',
#  87: 'new',
#  88: 'out',
#  89: 'last',
#  90: 'ask',
#  91: 'am',
#  92: 'right?',
#  93: 'work',
#  94: 'might',
#  95: 'want',
#  96: 'after',
#  97: 'has',
#  98: 'really',
#  99: 'their',
#  100: 'much',
#  101: 'okay.',
#  102: 'sales',
#  103: 'no',
#  104: 'too.',
#  105: 'also',
#  106: 'got',
#  107: 'were',
#  108: 'did',
#  109: "let's",
#  110: 'that.',
#  111: "i'd",
#  112: 'mr.',
#  113: 'able',
#  114: 'meeting',
#  115: 'only',
#  116: 'could',
#  117: 'around',
#  118: 'let',
#  119: 'had',
#  120: 'since',
#  121: 'come',
#  122: 'talk',
#  123: 'use',
#  124: 'send',
#  125: 'something',
#  126: 'look',
#  127: 'product',
#  128: 'right',
#  129: 'sure',
#  130: "can't",
#  131: 'yeah,',
#  132: 'see',
#  133: 'first',
#  134: 'bit',
#  135: 'check',
#  136: 'even',
#  137: 'here',
#  138: 'than',
#  139: 'now',
#  140: 'us',
#  141: 'back',
#  142: 'many',
#  143: 'time.',
#  144: 'too',
#  145: 'now.',
#  146: 'two',
#  147: 'so,',
#  148: 'things',
#  149: 'where',
#  150: 'much.',
#  151: 'business',
#  152: 'because',
#  153: 'say',
#  154: 'training',
#  155: 'which',
#  156: 'order',
#  157: 'each',
#  158: 'it?',
#  159: 'seems',
#  160: 'him',
#  161: 'everyone',
#  162: 'end',
#  163: "i've",
#  164: 'right,',
#  165: 'start',
#  166: 'right.',
#  167: 'tell',
#  168: 'oh',
#  169: "you're",
#  170: 'name',
#  171: 'over',
#  172: 'may',
#  173: "didn't",
#  174: 'well.',
#  175: 'call',
#  176: 'day',
#  177: 'those',
#  178: 'give',
#  179: 'before',
#  180: 'same',
#  181: 'lot',
#  182: 'office',
#  183: 'year.',
#  184: 'maybe',
#  185: 'looking',
#  186: 'department',
#  187: 'see,',
#  188: 'anything',
#  189: 'employees',
#  190: 'why',
#  191: 'his',
#  192: 'then,',
#  193: 'person',
#  194: 'hello,',
#  195: 'today.',
#  196: 'working',
#  197: 'good.',
#  198: 'it,',
#  199: 'now,',
#  200: 'still',
#  201: 'see.',
#  202: 'does',
#  203: 'help',
#  204: 'try',
#  205: 'no,',
#  206: 'said',
#  207: 'number',
#  208: 'sounds',
#  209: 'long',
#  210: 'well',
#  211: 'better',
#  212: 'these',
#  213: 'feel',
#  214: 'then.',
#  215: 'you,',
#  216: 'yes.',
#  217: 'someone',
#  218: 'way',
#  219: 'though.',
#  220: 'forward',
#  221: 'thought',
#  222: 'change',
#  223: 'find',
#  224: 'year',
#  225: 'pretty',
#  226: 'three',
#  227: 'sorry',
#  228: 'keep',
#  229: "won't",
#  230: "doesn't",
#  231: "isn't",
#  232: 'actually',
#  233: 'email',
#  234: 'you?',
#  235: 'planning',
#  236: 'system',
#  237: 'thinking',
#  238: 'schedule',
#  239: 'such',
#  240: 'wanted',
#  241: '2',
#  242: 'leave',
#  243: 'day.',
#  244: 'lunch',
#  245: 'tomorrow.',
#  246: 'using',
#  247: 'went',
#  248: 'ah,',
#  249: 'kind',
#  250: 'wait',
#  251: 'general',
#  252: 'until',
#  253: 'once',
#  254: 'room',
#  255: 'asked',
#  256: 'information',
#  257: 'during',
#  258: 'put',
#  259: 'heard',
#  260: 'price',
#  261: "we're",
#  262: 'made',
#  263: 'also,',
#  264: 'hard',
#  265: 'please.',
#  266: 'me.',
#  267: 'bring',
#  268: 'days',
#  269: 'hear',
#  270: 'great',
#  271: 'fine.',
#  272: 'all,',
#  273: 'morning',
#  274: 'here.',
#  275: 'probably',
#  276: 'month',
#  277: 'different',
#  278: 'used',
#  279: 'food',
#  280: 'course.',
#  281: 'appreciate',
#  282: "there's",
#  283: 'japanese',
#  284: 'do.',
#  285: 'that,',
#  286: 'quite',
#  287: 'being',
#  288: 'big',
#  289: 'off',
#  290: 'week.',
#  291: 'set',
#  292: 'always',
#  293: 'place',
#  294: '3',
#  295: 'company.',
#  296: 'without',
#  297: 'department.',
#  298: 'hmm,',
#  299: 'really?',
#  300: 'meeting.',
#  301: 'charge',
#  302: 'doing',
#  303: 'them.',
#  304: 'cost',
#  305: 'week',
#  306: 'manager',
#  307: 'into',
#  308: 'looks',
#  309: 'know,',
#  310: 'ms.',
#  311: 'questions',
#  312: 'coming',
#  313: 'morning.',
#  314: 'speak',
#  315: 'now?',
#  316: 'yen',
#  317: 'wow,',
#  318: 'english',
#  319: 'her',
#  320: "we'll",
#  321: 'soon',
#  322: 'having',
#  323: 'however,',
#  324: 'hope',
#  325: 'while',
#  326: 'already',
#  327: 'taking',
#  328: 'project',
#  329: 'she',
#  330: 'this.',
#  331: 'plan',
#  332: '10',
#  333: "o'clock",
#  334: "what's",
#  335: 'data',
#  336: 'me,',
#  337: 'month.',
#  338: 'understand',
#  339: 'little',
#  340: 'hotel',
#  341: 'most',
#  342: 'way,',
#  343: 'there.',
#  344: 'possible',
#  345: 'every',
#  346: '5',
#  347: 'later.',
#  348: 'okay',
#  349: 'few',
#  350: 'show',
#  351: 'great.',
#  352: 'another',
#  353: 'details',
#  354: 'sure.',
#  355: 'products',
#  356: 'today',
#  357: 'through',
#  358: 'contact',
#  359: "haven't",
#  360: 'president',
#  361: 'wonder',
#  362: 'sure,',
#  363: 'staff',
#  364: 'buy',
#  365: 'explain',
#  366: 'but,',
#  367: 'making',
#  368: 'documents',
#  369: 'anyone',
#  370: 'here,',
#  371: 'time?',
#  372: 'office.',
#  373: 'nice',
#  374: 'moment.',
#  375: 'regards',
#  376: 'done',
#  377: 'meet',
#  378: 'customer',
#  379: 'work.',
#  380: 'morning,',
#  381: 'ok,',
#  382: 'train',
#  383: 'out.',
#  384: 'alright,',
#  385: 'time,',
#  386: 'years',
#  387: 'important',
#  388: 'again',
#  389: 'hi,',
#  390: '1',
#  391: 'own',
#  392: 'guys',
#  393: "company's",
#  394: 'down',
#  395: 'current',
#  396: 'c',
#  397: 'getting',
#  398: 'increase',
#  399: 'team',
#  400: 'part',
#  401: 'sorry,',
#  402: "aren't",
#  403: 'b',
#  404: 'true.',
#  405: 'best',
#  406: 'told',
#  407: 'eat',
#  408: 'everything',
#  409: 'times',
#  410: 'today,',
#  411: 'case,',
#  412: 'thing',
#  413: 'busy',
#  414: 'request',
#  415: 'know.',
#  416: 'care',
#  417: 'decided',
#  418: 'enough',
#  419: 'year,',
#  420: 'customers',
#  421: 'division',
#  422: 'small',
#  423: 'later',
#  424: "wasn't",
#  425: 'budget',
#  426: 'market',
#  427: 'report',
#  428: 'home',
#  429: 'high',
#  430: 'party',
#  431: 'security',
#  432: 'yes',
#  433: 'school',
#  434: 'um,',
#  435: 'hr',
#  436: 'development',
#  437: 'easy',
#  438: 'companies',
#  439: 'open',
#  440: 'came',
#  441: "you'd",
#  442: 'under',
#  443: 'case',
#  444: 'issue',
#  445: 'comes',
#  446: 'makes',
#  447: 'love',
#  448: 'both',
#  449: "it'll",
#  450: 'paid',
#  451: 'date',
#  452: 'actually,',
#  453: "we've",
#  454: "you've",
#  455: 'fine',
#  456: 'talking',
#  457: 'away.',
#  458: 'travel',
#  459: 'phone',
#  460: 'ok',
#  461: 'company,',
#  462: 'month,',
#  463: 'trip',
#  464: 'between',
#  465: 'sent',
#  466: 'large',
#  467: 'document',
#  468: 'public',
#  469: 'people.',
#  470: 'today?',
#  471: 'discuss',
#  472: 'service',
#  473: 'pay',
#  474: 'items',
#  475: 'called',
#  476: 'add',
#  477: "you'll",
#  478: 'great,',
#  479: 'started',
#  480: 'restaurant',
#  481: 'interested',
#  482: 'pick',
#  483: 'problem',
#  484: 'glad',
#  485: 'per',
#  486: 'clients',
#  487: 'marketing',
#  488: 'all.',
#  489: 'days.',
#  490: 'free',
#  491: 'up.',
#  492: 'else',
#  493: 'usually',
#  494: 'decide',
#  495: 'year?',
#  496: 'gets',
#  497: 'early',
#  498: 'remember',
#  499: 'must',
#  500: 'move',
#  501: 'lots',
#  502: 'support',
#  503: 'again.',
#  504: 'first.',
#  505: '30',
#  506: 'members',
#  507: 'head',
#  508: 'application',
#  509: 'several',
#  510: 'excuse',
#  511: 'store',
#  512: 'is.',
#  513: 'help.',
#  514: 'client',
#  515: 'amount',
#  516: 'true,',
#  517: 'prepare',
#  518: 'point',
#  519: 'week,',
#  520: 'idea',
#  521: 'first,',
#  522: 'tomorrow',
#  523: 'so.',
#  524: 'problem.',
#  525: 'additional',
#  526: 'management',
#  527: 'vacation',
#  528: 'think?',
#  529: 'top',
#  530: 'that?',
#  531: 'never',
#  532: 'course',
#  533: 'employee',
#  534: 'offer',
#  535: 'near',
#  536: 'boss',
#  537: 'course,',
#  538: 'due',
#  539: 'stay',
#  540: 'old',
#  541: 'read',
#  542: 'coffee',
#  543: 'commuting',
#  544: 'calling',
#  545: 'whole',
#  546: 'worried',
#  547: 'months',
#  548: 'based',
#  549: 'visit',
#  550: 'within',
#  551: 'one.',
#  552: 'card',
#  553: 'left',
#  554: 'department,',
#  555: '20',
#  556: 'believe',
#  557: 'starting',
#  558: 'needs',
#  559: 'mean',
#  560: "wouldn't",
#  561: 'close',
#  562: 'job',
#  563: 'asking',
#  564: 'insurance',
#  565: 'looked',
#  566: 'cannot',
#  567: 'and,',
#  568: 'half',
#  569: "couldn't",
#  570: 'ten',
#  571: 'us.',
#  572: 'minutes',
#  573: 'process',
#  574: 'quote',
#  575: 'experience',
#  576: 'back.',
#  577: 'took',
#  578: 'a.',
#  579: 'weeks',
#  580: 'understand.',
#  581: 'inspection',
#  582: 'idea.',
#  583: 'definitely',
#  584: 'found',
#  585: 'bad',
#  586: 'contract',
#  587: 'family',
#  588: 'happy',
#  589: 'japan',
#  590: 'saw',
#  591: 'system.',
#  592: 'it’s',
#  593: 'there?',
#  594: 'available',
#  595: 'review',
#  596: 'on.',
#  597: 'board',
#  598: 'quarter.',
#  599: 'mentioned',
#  600: 'especially',
#  601: 'received',
#  602: 'mind',
#  603: 'currently',
#  604: 'certainly.',
#  605: 'percent',
#  606: 'issues',
#  607: 'means',
#  608: 'book',
#  609: 'together',
#  610: 'station',
#  611: 'possible.',
#  612: 'departments',
#  613: 'flight',
#  614: 'shall',
#  615: 'can.',
#  616: '15',
#  617: 'regarding',
#  618: 'know?',
#  619: 'proceed',
#  620: 'answer',
#  621: "year's",
#  622: 'side',
#  623: 'yet.',
#  624: 'difference',
#  625: 'break',
#  626: 'middle',
#  627: 'earlier',
#  628: 'good,',
#  629: 'hold',
#  630: 'wants',
#  631: 'hand',
#  632: 'notice',
#  633: 'prefer',
#  634: 'difficult',
#  635: 'you!',
#  636: 'okay?',
#  637: 'hello',
#  638: 'thousand',
#  639: 'yeah.',
#  640: 'learn',
#  641: 'wife',
#  642: 'entire',
#  643: "he's",
#  644: 'file',
#  645: 'hi',
#  646: 'ago.',
#  647: 'front',
#  648: 'director',
#  649: 'past',
#  650: 'various',
#  651: '4',
#  652: 'area',
#  653: 'return',
#  654: 'apply',
#  655: 'too?',
#  656: '6',
#  657: 'away',
#  658: 'saying',
#  659: 'become',
#  660: 'food.',
#  661: 'nothing',
#  662: 'building',
#  663: 'though',
#  664: 'arrange',
#  665: 'group',
#  666: 'dinner',
#  667: 'car',
#  668: 'almost',
#  669: 'says',
#  670: 'yen.',
#  671: 'goes',
#  672: 'really,',
#  673: 'accounting',
#  674: "they're",
#  675: 'shareholders',
#  676: 'list',
#  677: 'm',
#  678: 'meetings',
#  679: 'finished',
#  680: 'room.',
#  681: 'often',
#  682: 'regular',
#  683: 'again,',
#  684: 'day,',
#  685: 'finish',
#  686: 'rest',
#  687: 'design',
#  688: 'hours',
#  689: 'supposed',
#  690: "o'clock.",
#  691: 'wondering',
#  692: 'press',
#  693: 'emergency',
#  694: 'guess',
#  695: 'write',
#  696: 'five',
#  697: 'japan.',
#  698: 'friday',
#  699: 'online',
#  700: 'outside',
#  701: 'sale',
#  702: 'trainings',
#  703: 'provide',
#  704: 'everyone.',
#  705: 'worry',
#  706: 'checked',
#  707: 'seem',
#  708: 'ordered',
#  709: 'arrive',
#  710: 'deal',
#  711: 'invoice',
#  712: 'call.',
#  713: 'information.',
#  714: 'share',
#  715: 'ahead',
#  716: 'floor',
#  717: 'interview',
#  718: 'compared',
#  719: 'green',
#  720: 'a,',
#  721: 'rather',
#  722: 'chance',
#  723: 'choose',
#  724: 'g',
#  725: 'live',
#  726: 'tea',
#  727: 'person.',
#  728: 'far',
#  729: 'hassle',
#  730: 'years.',
#  731: 'home.',
#  732: 'school.',
#  733: 'recently.',
#  734: 'me?',
#  735: 'city',
#  736: 'before.',
#  737: 'then?',
#  738: 'record',
#  739: 'pleasure',
#  740: "we'd",
#  741: 'i’m',
#  742: 'materials',
#  743: 'among',
#  744: 'including',
#  745: 'improve',
#  746: 'stop',
#  747: 'earlier,',
#  748: 'further',
#  749: 'total',
#  750: 'afternoon',
#  751: 's',
#  752: 'similar',
#  753: 'tv',
#  754: 'seen',
#  755: 'special',
#  756: 'parts',
#  757: 'extra',
#  758: 'reason',
#  759: 'introduce',
#  760: 'enjoy',
#  761: 'confirm',
#  762: 'commute',
#  763: 'include',
#  764: 'well?',
#  765: 'turn',
#  766: 'selling',
#  767: 'too,',
#  768: 'there,',
#  769: 'possible,',
#  770: 'submit',
#  771: 'easier',
#  772: 'drink',
#  773: 'higher',
#  774: 'four',
#  775: 'trying',
#  776: 'what,',
#  777: 'sales,',
#  778: 'tokyo',
#  779: 'least',
#  780: 'team.',
#  781: 'hearing',
#  782: 'event',
#  783: 'approval',
#  784: 'computer',
#  785: 'promotion',
#  786: 'tanaka',
#  787: 'delivery',
#  788: 'dog',
#  789: 'sato',
#  790: 'that’s',
#  791: 'i’d',
#  792: 'always.',
#  793: 'hour',
#  794: 'thirty',
#  795: 'material',
#  796: 'corporate',
#  797: 'venue',
#  798: 'go.',
#  799: 'situation',
#  800: 'name.',
#  801: 'terms',
#  802: 'results',
#  803: 'sending',
#  804: 'directly',
#  805: 'afternoon.',
#  806: 'message',
#  807: 'money',
#  808: 'moment',
#  809: 'fee',
#  810: 'issue.',
#  811: "today's",
#  812: 'work,',
#  813: 'therefore,',
#  814: 'payment',
#  815: 'sales.',
#  816: 'page',
#  817: 'b.',
#  818: 'transfer',
#  819: 'hire',
#  820: 'plan.',
#  821: 'rate',
#  822: 'leaving',
#  823: 'create',
#  824: 'section',
#  825: 'like,',
#  826: 'd',
#  827: 'research',
#  828: 'one,',
#  829: 'h',
#  830: 'yet,',
#  831: 'drinks',
#  832: 'soon.',
#  833: 'wear',
#  834: 'schedule.',
#  835: 'together.',
#  836: 'somewhere',
#  837: 'estimate',
#  838: 'felt',
#  839: 'space',
#  840: 'changed',
#  841: 'quickly',
#  842: 'students',
#  843: 'size',
#  844: 'reduce',
#  845: 'guest',
#  846: 'store.',
#  847: 'exchange',
#  848: 'million',
#  849: 'sometimes',
#  850: 'maternity',
#  851: 'handle',
#  852: 'questions?',
#  853: 'along',
#  854: 'system,',
#  855: 'umm,',
#  856: 'error',
#  857: 'staying',
#  858: 'desk',
#  859: 'tasks',
#  860: 'particular',
#  861: 'main',
#  862: 'please?',
#  863: 'presentation',
#  864: 'party.',
#  865: 'corporation.',
#  866: 'longer',
#  867: 'switch',
#  868: 'earlier.',
#  869: 'tomorrow?',
#  870: 'overall',
#  871: 'select',
#  872: 'meeting,',
#  873: 'performance',
#  874: 'stock',
#  875: 'changing',
#  876: 'drop',
#  877: 'second',
#  878: 'late',
#  879: 'content',
#  880: 'points',
#  881: 'correct.',
#  882: 'bought',
#  883: 'fixed',
#  884: 'thanks',
#  885: 'with?',
#  886: 'happen',
#  887: 'day?',
#  888: 'website',
#  889: 'calling.',
#  890: 'more.',
#  891: 'exactly.',
#  892: 'tour',
#  893: 'listed',
#  894: 'country',
#  895: 'best.',
#  896: 'appointment',
#  897: "shouldn't",
#  898: 'here?',
#  899: 'setting',
#  900: 'ready',
#  901: 'sign',
#  902: 'basic',
#  903: 'walk',
#  904: 'takes',
#  905: 'anything.',
#  906: 'conversation',
#  907: 'cut',
#  908: 'prices',
#  909: 'transportation',
#  910: 'park',
#  911: 'yesterday.',
#  912: 'serve',
#  913: 'egg',
#  914: 'yet',
#  915: 'survey',
#  916: 'instead',
#  917: 'example,',
#  918: 'language',
#  919: 'months.',
#  920: 'june',
#  921: 'health',
#  922: 'fill',
#  923: 'while.',
#  924: 'too!',
#  925: 'gift',
#  926: 'program',
#  927: 'in.',
#  928: 'click',
#  929: 'address',
#  930: 'done.',
#  931: 'expense',
#  932: 'cold',
#  933: 'training.',
#  934: 'on,',
#  935: 'teach',
#  936: 'bulletin',
#  937: 'skills',
#  938: 'young',
#  939: 'types',
#  940: 'consider',
#  941: 'don’t',
#  942: 'according',
#  943: 'actual',
#  944: 'needed.',
#  945: 'thing.',
#  946: 'questions.',
#  947: 'exactly',
#  948: 'hoping',
#  949: 'detailed',
#  950: 'newly',
#  951: 'next,',
#  952: 'feeling',
#  953: 'needed',
#  954: 'things.',
#  955: 'fine,',
#  956: 'bye',
#  957: 'plans',
#  958: 'like.',
#  959: 'moment?',
#  960: 'requests',
#  961: 'easily',
#  962: 'important.',
#  963: 'about.',
#  964: 'delivered',
#  965: 'product?',
#  966: 'refund',
#  967: 'shipping',
#  968: 'credit',
#  969: 'product.',
#  970: 'everyone,',
#  971: 'week?',
#  972: 'like?',
#  973: 'hello.',
#  974: 'deadline',
#  975: 'final',
#  976: 'shows',
#  977: 'about?',
#  978: 'opinion',
#  979: 'quick',
#  980: 'creating',
#  981: 'opportunity',
#  982: 'logo',
#  983: 'products.',
#  984: 'everybody',
#  985: 'expect',
#  986: 'human',
#  987: 'late.',
#  988: 'exactly,',
#  989: 'far.',
#  990: 'lot.',
#  991: 'opinions',
#  992: 'fun',
#  993: 'talked',
#  994: 'expecting',
#  995: 'tomorrow,',
#  996: 'liked',
#  997: 'employees.',
#  998: 'eight',
#  999: '12',
#  1000: 'type',
#  ...}

# %%
vocabulary_size = len(tokenizer.word_counts)+1
vocabulary_size
# Out:
# 9774

# %%
sequences = np.array(sequences)
sequences.shape
# Out:
# (99691, 6)

# %%
from keras.layers import Embedding, Bidirectional, GRU, Dropout, Dense, Conv1D, GlobalMaxPooling1D
model = Sequential()
model.add(Embedding(vocabulary_size, 50, input_length=5))
model.add(Dense(units=64, activation='relu'))
model.add(Dense(units=32, activation='relu'))
model.add(Conv1D(32,1,activation="relu"))
model.add(GlobalMaxPooling1D())

model.add(Dense(vocabulary_size, activation='softmax', activity_regularizer=regularizers.L2(0.001)))

model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 5, 50)             488700
#
#  dense_4 (Dense)             (None, 5, 64)             3264
#
#  dense_5 (Dense)             (None, 5, 32)             2080
#
#  conv1d_1 (Conv1D)           (None, 5, 32)             1056
#
#  global_max_pooling1d (Glob  (None, 32)                0
#  alMaxPooling1D)
#
#  dense_6 (Dense)             (None, 9774)              322542
#
# =================================================================
# Total params: 817642 (3.12 MB)
# Trainable params: 817642 (3.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
X = sequences[:,:-1]
X.shape
# Out:
# (99691, 5)

# %%
Y = sequences[:,-1]
del sequences
Y.shape
# Out:
# (99691,)

# %%
Y = to_categorical(Y, num_classes=vocabulary_size)
Y.shape
# Out:
# (99691, 9774)

# %%
from sklearn.utils import shuffle
X, Y = shuffle(X, Y)

# %%
his = model.fit(X, Y, batch_size=256, epochs=75,verbose=1,validation_split=0.1)
# Out:
# Epoch 1/75
# 351/351 [==============================] - 26s 60ms/step - loss: 7.1202 - accuracy: 0.0410 - val_loss: 6.8294 - val_accuracy: 0.0434
# Epoch 2/75
# 351/351 [==============================] - 8s 23ms/step - loss: 6.6743 - accuracy: 0.0451 - val_loss: 6.8467 - val_accuracy: 0.0450
# Epoch 3/75
# 351/351 [==============================] - 9s 26ms/step - loss: 6.5935 - accuracy: 0.0473 - val_loss: 6.8801 - val_accuracy: 0.0474
# Epoch 4/75
# 351/351 [==============================] - 8s 21ms/step - loss: 6.5036 - accuracy: 0.0522 - val_loss: 6.9261 - val_accuracy: 0.0518
# Epoch 5/75
# 351/351 [==============================] - 7s 20ms/step - loss: 6.4017 - accuracy: 0.0597 - val_loss: 6.9526 - val_accuracy: 0.0578
# Epoch 6/75
# 351/351 [==============================] - 8s 22ms/step - loss: 6.2719 - accuracy: 0.0678 - val_loss: 6.9671 - val_accuracy: 0.0617
# Epoch 7/75
# 351/351 [==============================] - 8s 22ms/step - loss: 6.1425 - accuracy: 0.0738 - val_loss: 7.0157 - val_accuracy: 0.0672
# Epoch 8/75
# 351/351 [==============================] - 7s 21ms/step - loss: 6.0216 - accuracy: 0.0789 - val_loss: 7.0563 - val_accuracy: 0.0711
# Epoch 9/75
# 351/351 [==============================] - 7s 20ms/step - loss: 5.8946 - accuracy: 0.0851 - val_loss: 7.1387 - val_accuracy: 0.0739
# Epoch 10/75
# 351/351 [==============================] - 7s 19ms/step - loss: 5.7652 - accuracy: 0.0888 - val_loss: 7.2207 - val_accuracy: 0.0746
# Epoch 11/75
# 351/351 [==============================] - 7s 21ms/step - loss: 5.6324 - accuracy: 0.0929 - val_loss: 7.3579 - val_accuracy: 0.0729
# Epoch 12/75
# 351/351 [==============================] - 6s 18ms/step - loss: 5.4967 - accuracy: 0.0950 - val_loss: 7.5320 - val_accuracy: 0.0753
# Epoch 13/75
# 351/351 [==============================] - 7s 21ms/step - loss: 5.3607 - accuracy: 0.0976 - val_loss: 7.7431 - val_accuracy: 0.0733
# Epoch 14/75
# 351/351 [==============================] - 7s 19ms/step - loss: 5.2266 - accuracy: 0.1013 - val_loss: 8.0069 - val_accuracy: 0.0736
# Epoch 15/75
# 351/351 [==============================] - 8s 22ms/step - loss: 5.1026 - accuracy: 0.1050 - val_loss: 8.2718 - val_accuracy: 0.0754
# Epoch 16/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.9906 - accuracy: 0.1145 - val_loss: 8.5352 - val_accuracy: 0.0680
# Epoch 17/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.8952 - accuracy: 0.1292 - val_loss: 8.7788 - val_accuracy: 0.0688
# Epoch 18/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.8146 - accuracy: 0.1415 - val_loss: 9.0016 - val_accuracy: 0.0673
# Epoch 19/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.7467 - accuracy: 0.1525 - val_loss: 9.1622 - val_accuracy: 0.0661
# Epoch 20/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.6891 - accuracy: 0.1595 - val_loss: 9.3133 - val_accuracy: 0.0658
# Epoch 21/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.6410 - accuracy: 0.1641 - val_loss: 9.4203 - val_accuracy: 0.0638
# Epoch 22/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.5988 - accuracy: 0.1705 - val_loss: 9.6472 - val_accuracy: 0.0634
# Epoch 23/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.5644 - accuracy: 0.1738 - val_loss: 9.8144 - val_accuracy: 0.0611
# Epoch 24/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.5327 - accuracy: 0.1771 - val_loss: 9.8778 - val_accuracy: 0.0642
# Epoch 25/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.5059 - accuracy: 0.1788 - val_loss: 10.0208 - val_accuracy: 0.0631
# Epoch 26/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.4812 - accuracy: 0.1818 - val_loss: 10.0872 - val_accuracy: 0.0624
# Epoch 27/75
# 351/351 [==============================] - 6s 18ms/step - loss: 4.4587 - accuracy: 0.1840 - val_loss: 10.2069 - val_accuracy: 0.0608
# Epoch 28/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.4383 - accuracy: 0.1863 - val_loss: 10.4260 - val_accuracy: 0.0610
# Epoch 29/75
# 351/351 [==============================] - 6s 18ms/step - loss: 4.4214 - accuracy: 0.1882 - val_loss: 10.4853 - val_accuracy: 0.0606
# Epoch 30/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.4032 - accuracy: 0.1902 - val_loss: 10.5622 - val_accuracy: 0.0616
# Epoch 31/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.3853 - accuracy: 0.1923 - val_loss: 10.7432 - val_accuracy: 0.0622
# Epoch 32/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.3708 - accuracy: 0.1942 - val_loss: 10.8747 - val_accuracy: 0.0597
# Epoch 33/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.3570 - accuracy: 0.1956 - val_loss: 10.9191 - val_accuracy: 0.0600
# Epoch 34/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.3452 - accuracy: 0.1976 - val_loss: 11.0202 - val_accuracy: 0.0601
# Epoch 35/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.3317 - accuracy: 0.1989 - val_loss: 10.9977 - val_accuracy: 0.0594
# Epoch 36/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.3208 - accuracy: 0.1995 - val_loss: 11.2203 - val_accuracy: 0.0605
# Epoch 37/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.3093 - accuracy: 0.2012 - val_loss: 11.3806 - val_accuracy: 0.0600
# Epoch 38/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.2996 - accuracy: 0.2016 - val_loss: 11.4819 - val_accuracy: 0.0627
# Epoch 39/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.2898 - accuracy: 0.2034 - val_loss: 11.5730 - val_accuracy: 0.0609
# Epoch 40/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.2788 - accuracy: 0.2052 - val_loss: 11.5949 - val_accuracy: 0.0600
# Epoch 41/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.2705 - accuracy: 0.2057 - val_loss: 11.6679 - val_accuracy: 0.0590
# Epoch 42/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.2629 - accuracy: 0.2065 - val_loss: 11.8202 - val_accuracy: 0.0612
# Epoch 43/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.2540 - accuracy: 0.2077 - val_loss: 11.8421 - val_accuracy: 0.0609
# Epoch 44/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.2452 - accuracy: 0.2085 - val_loss: 11.9914 - val_accuracy: 0.0589
# Epoch 45/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.2383 - accuracy: 0.2095 - val_loss: 12.0409 - val_accuracy: 0.0573
# Epoch 46/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.2305 - accuracy: 0.2111 - val_loss: 12.1498 - val_accuracy: 0.0603
# Epoch 47/75
# 351/351 [==============================] - 7s 18ms/step - loss: 4.2241 - accuracy: 0.2111 - val_loss: 12.2642 - val_accuracy: 0.0571
# Epoch 48/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.2177 - accuracy: 0.2122 - val_loss: 12.3214 - val_accuracy: 0.0584
# Epoch 49/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.2089 - accuracy: 0.2127 - val_loss: 12.3968 - val_accuracy: 0.0594
# Epoch 50/75
# 351/351 [==============================] - 8s 22ms/step - loss: 4.2041 - accuracy: 0.2132 - val_loss: 12.4248 - val_accuracy: 0.0584
# Epoch 51/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1981 - accuracy: 0.2151 - val_loss: 12.5666 - val_accuracy: 0.0587
# Epoch 52/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1920 - accuracy: 0.2144 - val_loss: 12.6723 - val_accuracy: 0.0606
# Epoch 53/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1851 - accuracy: 0.2158 - val_loss: 12.7856 - val_accuracy: 0.0602
# Epoch 54/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1809 - accuracy: 0.2156 - val_loss: 12.7242 - val_accuracy: 0.0589
# Epoch 55/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1743 - accuracy: 0.2170 - val_loss: 12.8571 - val_accuracy: 0.0589
# Epoch 56/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1692 - accuracy: 0.2180 - val_loss: 12.9631 - val_accuracy: 0.0591
# Epoch 57/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.1631 - accuracy: 0.2181 - val_loss: 13.1216 - val_accuracy: 0.0570
# Epoch 58/75
# 351/351 [==============================] - 6s 18ms/step - loss: 4.1611 - accuracy: 0.2181 - val_loss: 13.0196 - val_accuracy: 0.0558
# Epoch 59/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1554 - accuracy: 0.2189 - val_loss: 13.0940 - val_accuracy: 0.0564
# Epoch 60/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1499 - accuracy: 0.2210 - val_loss: 13.2001 - val_accuracy: 0.0596
# Epoch 61/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1457 - accuracy: 0.2209 - val_loss: 13.1996 - val_accuracy: 0.0566
# Epoch 62/75
# 351/351 [==============================] - 6s 18ms/step - loss: 4.1401 - accuracy: 0.2219 - val_loss: 13.3433 - val_accuracy: 0.0550
# Epoch 63/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1354 - accuracy: 0.2213 - val_loss: 13.4436 - val_accuracy: 0.0568
# Epoch 64/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1318 - accuracy: 0.2222 - val_loss: 13.3973 - val_accuracy: 0.0567
# Epoch 65/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1268 - accuracy: 0.2233 - val_loss: 13.5062 - val_accuracy: 0.0562
# Epoch 66/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1244 - accuracy: 0.2234 - val_loss: 13.5120 - val_accuracy: 0.0570
# Epoch 67/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1206 - accuracy: 0.2239 - val_loss: 13.6058 - val_accuracy: 0.0574
# Epoch 68/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1158 - accuracy: 0.2244 - val_loss: 13.8196 - val_accuracy: 0.0575
# Epoch 69/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1120 - accuracy: 0.2247 - val_loss: 13.8222 - val_accuracy: 0.0591
# Epoch 70/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.1094 - accuracy: 0.2249 - val_loss: 13.8407 - val_accuracy: 0.0577
# Epoch 71/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.1048 - accuracy: 0.2258 - val_loss: 13.8099 - val_accuracy: 0.0592
# Epoch 72/75
# 351/351 [==============================] - 7s 20ms/step - loss: 4.1022 - accuracy: 0.2267 - val_loss: 14.0095 - val_accuracy: 0.0582
# Epoch 73/75
# 351/351 [==============================] - 7s 19ms/step - loss: 4.0971 - accuracy: 0.2263 - val_loss: 13.9570 - val_accuracy: 0.0575
# Epoch 74/75
# 351/351 [==============================] - 7s 21ms/step - loss: 4.0941 - accuracy: 0.2271 - val_loss: 14.1196 - val_accuracy: 0.0562
# Epoch 75/75
# 351/351 [==============================] - 6s 18ms/step - loss: 4.0907 - accuracy: 0.2281 - val_loss: 14.1610 - val_accuracy: 0.0555

# %%
# Sleep for a few seconds.
import time
time.sleep(2)

# Play an audio beep. Any audio URL will do.
from google.colab import output
output.eval_js('new Audio("https://upload.wikimedia.org/wikipedia/commons/0/05/Beep-09.ogg").play()')

# %%
# save the model to file
model.save('cnnn5epoch100.h5')
# save the tokenizer
pickle.dump(tokenizer, open('cnnn5tok.sav', 'wb'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import matplotlib.pyplot as plt

plt.plot(his.history['accuracy'])
plt.plot(his.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
plt.plot(his.history['loss'])
plt.plot(his.history['val_loss'])
plt.title('Model Loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
from keras.preprocessing.sequence import pad_sequences

def generate_text(model, tokenizer, seq_len, seed_text, num_gen_words):
    '''
    INPUTS:
    model : model that was trained on text data
    tokenizer : tokenizer that was fit on text data
    seq_len : length of training sequence
    seed_text : raw string text to serve as the seed
    num_gen_words : number of words to be generated by model
    '''

    # Final Output
    output_text = []

    # Intial Seed Sequence
    input_text = seed_text

    # Create num_gen_words
    for i in range(num_gen_words):

        # Take the input text string and encode it to a sequence
        encoded_text = tokenizer.texts_to_sequences([input_text])[0]

        # Pad sequences to our trained rate (25 words in the video)
        pad_encoded = pad_sequences([encoded_text], maxlen=seq_len, truncating='pre')

        # Predict Class Probabilities for each word
        #pred_word_ind = model.predict_classes(pad_encoded, verbose=0)[0]
        predict_x=model.predict(pad_encoded)
        pred_word_ind=np.argmax(predict_x,axis=1)[0]
        #print(pred_word_ind)
        # Grab word
        pred_word = tokenizer.index_word[pred_word_ind]

        # Update the sequence of input text (shifting one over with the new word)
        input_text += ' ' + pred_word

        output_text.append(pred_word)

    # Make it look like a sentence.
    return ' '.join(output_text)

# %%
generate_text(model,tokenizer,5,seed_text="The quick brown fox jumps",num_gen_words=3)
# Out:
# 1/1 [==============================] - 0s 241ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 24ms/step
# 'spots classes. the'
